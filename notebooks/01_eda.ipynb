# %% [markdown]
# # 🧪 Exploratory Data Analysis (EDA)
# ### Health Insurance ML Project
#
# This notebook performs initial data loading, inspection, and exploratory analysis to understand the structure and quality of the dataset.

# %% [markdown]
# ## 📦 Import Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

sns.set(style="whitegrid")

# %% [markdown]
# ## 📁 Load Dataset

# %%
df = pd.read_csv("../data/insurance_synthetic.csv")
df.head()
# Out:
#    Customer ID  Age  Gender Marital Status    Occupation  Income Level  \
# 0        84966   23  Female        Married  Entrepreneur         70541
# 1        95568   26    Male        Widowed       Manager         54168
# 2        10544   29  Female         Single  Entrepreneur         73899
# 3        77033   20    Male       Divorced  Entrepreneur         63381
# 4        88160   25  Female      Separated       Manager         38794
#
#      Education Level Geographic Information  Location Behavioral Data  ...  \
# 0   Associate Degree                Mizoram     37534         policy5  ...
# 1          Doctorate                    Goa     63304         policy5  ...
# 2   Associate Degree              Rajasthan     53174         policy5  ...
# 3  Bachelor's Degree                 Sikkim     22803         policy5  ...
# 4  Bachelor's Degree            West Bengal     92858         policy1  ...
#
#   Customer Preferences Preferred Communication Channel Preferred Contact Time  \
# 0                Email               In-Person Meeting              Afternoon
# 1                 Mail               In-Person Meeting                Morning
# 2                Email                            Mail                Evening
# 3                 Text               In-Person Meeting                Anytime
# 4                Email                            Text               Weekends
#
#    Preferred Language Risk Profile Previous Claims History  Credit Score  \
# 0             English            1                       3           728
# 1              French            1                       2           792
# 2              German            2                       1           719
# 3              French            3                       0           639
# 4             English            0                       3           720
#
#      Driving Record  Life Events Segmentation Group
# 0               DUI   Job Change           Segment5
# 1             Clean   Retirement           Segment5
# 2          Accident   Childbirth           Segment3
# 3               DUI   Job Change           Segment3
# 4  Major Violations   Childbirth           Segment2
#
# [5 rows x 30 columns]

# %% [markdown]
# ## 📊 Basic Dataset Overview
# Check shape, columns, missing values, and summary statistics.

# %%
print("Shape:")
df.shape
# Out:
# Shape:
# (53503, 30)

# %%
print("Columns:")
df.columns.tolist()
# Out:
# Columns:
# ['Customer ID',
#  'Age',
#  'Gender',
#  'Marital Status',
#  'Occupation',
#  'Income Level',
#  'Education Level',
#  'Geographic Information',
#  'Location',
#  'Behavioral Data',
#  'Purchase History',
#  'Policy Start Date',
#  'Policy Renewal Date',
#  'Claim History',
#  'Interactions with Customer Service',
#  'Insurance Products Owned',
#  'Coverage Amount',
#  'Premium Amount',
#  'Deductible',
#  'Policy Type',
#  'Customer Preferences',
#  'Preferred Communication Channel',
#  'Preferred Contact Time',
#  'Preferred Language',
#  'Risk Profile',
#  'Previous Claims History',
#  'Credit Score',
#  'Driving Record',
#  'Life Events',
#  'Segmentation Group']

# %%
print("Missing values:")
df.isnull().sum()
# Out:
# Missing values:
# Customer ID                           0
# Age                                   0
# Gender                                0
# Marital Status                        0
# Occupation                            0
# Income Level                          0
# Education Level                       0
# Geographic Information                0
# Location                              0
# Behavioral Data                       0
# Purchase History                      0
# Policy Start Date                     0
# Policy Renewal Date                   0
# Claim History                         0
# Interactions with Customer Service    0
# Insurance Products Owned              0
# Coverage Amount                       0
# Premium Amount                        0
# Deductible                            0
# Policy Type                           0
# Customer Preferences                  0
# Preferred Communication Channel       0
# Preferred Contact Time                0
# Preferred Language                    0
# Risk Profile                          0
# Previous Claims History               0
# Credit Score                          0
# Driving Record                        0
# Life Events                           0
# Segmentation Group                    0
# dtype: int64

# %%
df.describe(include="all")
# Out:
#           Customer ID           Age Gender Marital Status   Occupation  \
# count    53503.000000  53503.000000  53503          53503        53503
# unique            NaN           NaN      2              5            9
# top               NaN           NaN   Male        Married  Salesperson
# freq              NaN           NaN  27499          13219         7919
# mean     52265.204998     44.140945    NaN            NaN          NaN
# std      28165.000067     15.079486    NaN            NaN          NaN
# min          1.000000     18.000000    NaN            NaN          NaN
# 25%      28950.500000     32.000000    NaN            NaN          NaN
# 50%      55858.000000     43.000000    NaN            NaN          NaN
# 75%      76096.000000     57.000000    NaN            NaN          NaN
# max     100000.000000     70.000000    NaN            NaN          NaN
#
#          Income Level   Education Level Geographic Information      Location  \
# count    53503.000000             53503                  53503  53503.000000
# unique            NaN                 5                     35           NaN
# top               NaN  Associate Degree            Lakshadweep           NaN
# freq              NaN             12213                   2140           NaN
# mean     82768.324318               NaN                    NaN  53703.032017
# std      36651.075670               NaN                    NaN  25404.953911
# min      20001.000000               NaN                    NaN  10000.000000
# 25%      51568.500000               NaN                    NaN  31510.500000
# 50%      80719.000000               NaN                    NaN  55143.000000
# 75%     115973.500000               NaN                    NaN  74951.000000
# max     149999.000000               NaN                    NaN  99999.000000
#
#        Behavioral Data  ... Customer Preferences  \
# count            53503  ...                53503
# unique               5  ...                    5
# top            policy3  ...                 Mail
# freq             15761  ...                11887
# mean               NaN  ...                  NaN
# std                NaN  ...                  NaN
# min                NaN  ...                  NaN
# 25%                NaN  ...                  NaN
# 50%                NaN  ...                  NaN
# 75%                NaN  ...                  NaN
# max                NaN  ...                  NaN
#
#        Preferred Communication Channel Preferred Contact Time  \
# count                            53503                  53503
# unique                               5                      5
# top                  In-Person Meeting               Weekends
# freq                             14311                  14092
# mean                               NaN                    NaN
# std                                NaN                    NaN
# min                                NaN                    NaN
# 25%                                NaN                    NaN
# 50%                                NaN                    NaN
# 75%                                NaN                    NaN
# max                                NaN                    NaN
#
#         Preferred Language  Risk Profile Previous Claims History  \
# count                53503  53503.000000            53503.000000
# unique                   5           NaN                     NaN
# top                 German           NaN                     NaN
# freq                 14452           NaN                     NaN
# mean                   NaN      1.597107                1.669495
# std                    NaN      1.135433                1.097238
# min                    NaN      0.000000                0.000000
# 25%                    NaN      1.000000                1.000000
# 50%                    NaN      1.000000                2.000000
# 75%                    NaN      3.000000                3.000000
# max                    NaN      3.000000                3.000000
#
#         Credit Score  Driving Record  Life Events Segmentation Group
# count   53503.000000           53503        53503              53503
# unique           NaN               5            5                  5
# top              NaN           Clean     Marriage           Segment5
# freq             NaN           15051        13463              13976
# mean      673.318562             NaN          NaN                NaN
# std        99.226674             NaN          NaN                NaN
# min       500.000000             NaN          NaN                NaN
# 25%       586.000000             NaN          NaN                NaN
# 50%       668.000000             NaN          NaN                NaN
# 75%       753.000000             NaN          NaN                NaN
# max       850.000000             NaN          NaN                NaN
#
# [11 rows x 30 columns]

# %% [markdown]
# ## 🔍 Identify Numerical & Categorical Columns

# %%
numerical_cols = df.select_dtypes(include=[np.number]).columns.tolist()
categorical_cols = df.select_dtypes(exclude=[np.number]).columns.tolist()

print("Numerical Columns:\n", numerical_cols)
print("Categorical Columns:\n", categorical_cols)
# Out:
# Numerical Columns:
#  ['Customer ID', 'Age', 'Income Level', 'Location', 'Claim History', 'Coverage Amount', 'Premium Amount', 'Deductible', 'Risk Profile', 'Previous Claims History', 'Credit Score']
# Categorical Columns:
#  ['Gender', 'Marital Status', 'Occupation', 'Education Level', 'Geographic Information', 'Behavioral Data', 'Purchase History', 'Policy Start Date', 'Policy Renewal Date', 'Interactions with Customer Service', 'Insurance Products Owned', 'Policy Type', 'Customer Preferences', 'Preferred Communication Channel', 'Preferred Contact Time', 'Preferred Language', 'Driving Record', 'Life Events', 'Segmentation Group']

# %% [markdown]
# ## 🧩 Feature Groups (Based on Dataset Schema)
#
# This dataset contains the following logical feature groups:
#
# - **Demographics:** Age, Gender, Marital Status, Education Level
# - **Socioeconomic:** Occupation, Income Level, Credit Score
# - **Geographic:** Geographic Information, Location
# - **Behavioral:** Behavioral Data, Purchase History, Interactions with Customer Service
# - **Policy Details:** Policy Start Date, Policy Renewal Date, Policy Type
# - **Financial:** Coverage Amount, Premium Amount, Deductible
# - **Risk Indicators:** Risk Profile, Driving Record, Previous Claims History
# - **Preferences:** Customer Preferences, Preferred Communication Channel, Preferred Contact Time, Preferred Language
# - **Segmentation:** Segmentation Group (target for clustering)

# %% [markdown]
# ## 📈 Numerical Feature Distributions

# %%
rows = math.ceil(len(numerical_cols) / 2)

fig, axes = plt.subplots(rows, 2, figsize=(12, 4 * rows))
axes = axes.flatten() # convert 2D to 1D array

for idx, col in enumerate(numerical_cols):
    sns.histplot(df[col], kde=True, ax=axes[idx], color="teal")
    axes[idx].set_title(f"Distribution of {col}")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🧩 Categorical Feature Distributions

# %%
rows = math.ceil(len(categorical_cols) / 2)

fig, axes = plt.subplots(rows, 2, figsize=(12, 4 * rows))
axes = axes.flatten() # convert 2D to 1D array

for idx, col in enumerate(categorical_cols):
    sns.histplot(df[col], kde=True, ax=axes[idx], color="teal")
    axes[idx].set_title(f"Distribution of {col}")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🔥 Correlation Heatmap (Numerical Features)

# %%
plt.figure(figsize=(14,10))
sns.heatmap(df[numerical_cols].corr(), cmap="BuGn", annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ## 🎯 Segmentation Group Analysis

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Segmentation Group", data=df, color="teal")
plt.title("Distribution of Segmentation Groups")
plt.show()

# %% [markdown]
# ## ✅ Next Steps
#
# - Clean missing values
# - Encode categorical variables
# - Scale numerical features
# - Build clustering models (K-Means, DBSCAN, Hierarchical)
# - Build fraud detection models (if fraud label exists in future datasets)
# - Visualize clusters using PCA / t-SNE
# - Deploy using Flask + Streamlit
